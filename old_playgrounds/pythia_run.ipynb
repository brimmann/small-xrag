# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
model = AutoModelForCausalLM.from_pretrained("EleutherAI/pythia-70m-deduped")

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-70m-deduped")
# Out:
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]

# %%
message = "Capital of France is "
tokenized_message = tokenizer(message, return_tensors="pt")

# %%
tokenized_message
# Out:
# {'input_ids': tensor([[15614,  1562,   273,  6181,   310,   209]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
tokenizer.eos_token_id
# Out:
# 0

# %%
output = model.generate(input_ids=tokenized_message["input_ids"], attention_mask=tokenized_message["attention_mask"], do_sample=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.

# %%
completion = tokenizer.decode(output[0])

# %%
completion
# Out:
# 'Capital of France is \n\nnot one – see\n\nbut for those as a nation – or to those as a'
