# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model_name = "google/gemma-3-1b-pt"
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
message = "Paris is capital of"
tokenized_message = tokenizer(message, return_tensors="pt").to(device)

# %%
tokenized_message
# Out:
# {'input_ids': tensor([[    2, 50429,   563,  5279,   529]], device='cuda:0'), 'attention_mask': tensor([[1, 1, 1, 1, 1]], device='cuda:0')}

# %%
output = model.generate(**tokenized_message, max_length=100)

# %%
tokenizer.decode(output[0])
# Out:
# '<bos>Paris is capital of France with 12 million inhabitants, the 2nd largest city in Europe. Paris is the most visited city in France, with approximately 20 million tourists each year. Paris has many sites, palaces, churches, museums, restaurants and the famous Eiffel Tower and Arc de Triomphe. \nI am a tourist guide and translator in French-English, German-French, German-English, English-French, English-German and French-English, French'
